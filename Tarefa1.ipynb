# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusHenriqueOliveira/DesafioPratico/blob/main/Tarefa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Análise Exploratória dos Dados**
#
# Realize uma análise inicial dos dados:
#
# ○ Verifique a distribuição das variáveis (idade, renda, tempo no site, etc.).
#
# ○ Explore possíveis relações entre as variáveis independentes e a variável alvo (Compra).
#
# ○ Identifique valores ausentes ou inconsistências nos dados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arquivo = '/content/Dataset.csv'

# %%
df = pd.read_csv(arquivo)

# %%
df.head()
# Out:
#    Idade  Renda Anual (em $)    Gênero  Tempo no Site (min) Anúncio Clicado  \
# 0   29.0             30000.0  Feminino             5.741706             Não
# 1   58.0             50000.0  Feminino            21.885505             Sim
# 2   50.0             70000.0  Feminino             6.121339             Não
# 3   21.0            100000.0  Feminino            16.264925             Não
# 4   59.0             50000.0  Feminino            28.235667             Sim
#
#    Compra (0 ou 1)
# 0                0
# 1                0
# 2                1
# 3                0
# 4                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Idade                190 non-null    float64
#  1   Renda Anual (em $)   189 non-null    float64
#  2   Gênero               193 non-null    object
#  3   Tempo no Site (min)  200 non-null    float64
#  4   Anúncio Clicado      190 non-null    object
#  5   Compra (0 ou 1)      200 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#             Idade  Renda Anual (em $)  Tempo no Site (min)  Compra (0 ou 1)
# count  190.000000          189.000000           200.000000       200.000000
# mean    38.510526        58253.968254            17.349090         0.330000
# std     12.679918        25612.061811             7.724088         0.471393
# min     18.000000        30000.000000            -1.000000         0.000000
# 25%     28.000000        30000.000000            10.860240         0.000000
# 50%     38.000000        50000.000000            18.197552         0.000000
# 75%     50.000000        70000.000000            23.887341         1.000000
# max     59.000000       100000.000000            29.853484         1.000000

# %%
df.isnull().sum()
# Out:
# Idade                  10
# Renda Anual (em $)     11
# Gênero                  7
# Tempo no Site (min)     0
# Anúncio Clicado        10
# Compra (0 ou 1)         0
# dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['Idade'], kde=True, bins=30, color='blue')
plt.title('Distribuição de Idade')
plt.show()

plt.figure(figsize=(8, 4))
sns.histplot(df['Renda Anual (em $)'], kde=True, bins=10, color='green')
plt.title('Distribuição da Renda Anual (em $)')
plt.show()

plt.figure(figsize=(8, 4))
sns.histplot(df['Tempo no Site (min)'], kde=True, bins=30, color='red')
plt.title('Distribuição do Tempo no Site (min)')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gênero', color='pink')
plt.title('Distribuição de Gênero')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Anúncio Clicado', color='purple')
plt.title('Distribuição de Anúncio Clicado')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Compra (0 ou 1)', color='yellow')
plt.title('Distribuição de Compras')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Compra (0 ou 1)', y='Idade')
plt.title('Relaçao entre Idade e Compra')
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Compra (0 ou 1)', y='Renda Anual (em $)')
plt.title('Relaçao entre Renda Anual e Compra')
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Compra (0 ou 1)', y='Tempo no Site (min)')
plt.title('Relaçao entre Tempo no Site e Compra')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gênero', hue='Compra (0 ou 1)')
plt.title('Relação entre Gênero e Compra')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Anúncio Clicado', hue='Compra (0 ou 1)')
plt.title('Relação entre Anúncio Clicado e Compra')
plt.show()
